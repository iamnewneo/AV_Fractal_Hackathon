# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20, 6

# %%
from scipy.stats import skew

# %%
from scipy.special import inv_boxcox

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# %%
train_df.columns
# Out:
# Index(['ID', 'Item_ID', 'Datetime', 'Category_3', 'Category_2', 'Category_1',
#        'Price', 'Number_Of_Sales'],
#       dtype='object')

# %%
plt.scatter(np.log(train_df["Number_Of_Sales"]), train_df["Price"])

# %%
# pd.scatter_matrix(train_df[['Category_3', 'Category_2', 'Category_1',
#        'Price', 'Number_Of_Sales']], alpha = 0.3, figsize = (14,8), diagonal = 'kde');

# %%
ax = sns.kdeplot(train_df["Category_1"], shade=True, color="r")

# %%
ax = sns.kdeplot(np.log(train_df["Number_Of_Sales"]), shade=True, color="r")

# %%
ax = sns.kdeplot((train_df[train_df["Number_Of_Sales"] < 1000]["Number_Of_Sales"]), shade=True, color="r")

# %%
ax = sns.kdeplot(np.power(np.e,train_df["Number_Of_Sales"]), shade=True, color="r")

# %%
train_df["Number_Of_Sales"] = np.log(train_df["Number_Of_Sales"])

# %%
(train_df[train_df["Number_Of_Sales"] > 10000].shape[0])*100/train_df.shape[0]
# Out:
# 1.0754346416049423

# %%
train_df.describe()
# Out:
#              Item_ID     Category_3     Category_2     Category_1  \
# count  881876.000000  881876.000000  790263.000000  881876.000000
# mean    30517.396677       0.162506       2.755723     186.923135
# std       487.892582       0.368914       1.263769     130.754875
# min     29654.000000       0.000000       1.000000       0.000000
# 25%     30107.000000       0.000000       2.000000      70.000000
# 50%     30518.000000       0.000000       3.000000     176.000000
# 75%     30929.000000       0.000000       4.000000     307.000000
# max     31375.000000       1.000000       5.000000     413.000000
#
#                Price  Number_Of_Sales
# count  881876.000000    881876.000000
# mean        5.484011         5.354640
# std        22.472598         1.843942
# min         0.030000         0.000000
# 25%         0.125000         4.234107
# 50%         0.513000         5.476464
# 75%         2.070000         6.614726
# max       424.148000        13.301436

# %%
ax = sns.kdeplot((train_df["Price"]), shade=True, color="r")

# %%
(train_df[train_df["Price"] > 5].shape[0])*100/train_df.shape[0]

# %%
ax = sns.kdeplot(train_df[train_df["Price"] < 5]["Price"], shade=True, color="r")

# %%
ax = sns.kdeplot(train_df[train_df["Price"] < 5]["Price"], shade=True, color="r")

# %%
ax = sns.kdeplot((train_df["Category_1"]), shade=True, color="r")

# %%
train_df = train_df[train_df["Number_Of_Sales"] < 10000]
train_df = train_df[train_df["Price"] < 5]

# %%
skew(train_df["Number_Of_Sales"])

# %%
skew(train_df["Price"])

# %%
transformed_sales, lam = boxcox(train_df["Number_Of_Sales"])

# %%
ax = sns.kdeplot(transformed_sales, shade=True, color="r")
